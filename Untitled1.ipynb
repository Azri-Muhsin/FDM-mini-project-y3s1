# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
df = pd.read_csv("./data/normalized_data")

# %%
df = df.drop(columns=[ 'Unnamed: 0'])

# %%
scaleclms = ['YOJ','INCOME','HOME_VAL','BLUEBOOK','TRAVTIME','TIF','OLDCLAIM','CLM_FREQ','MVR_PTS', 'CAR_AGE', 'GEN_AGE']

# %%
scaler = MinMaxScaler()

# %%
df[scaleclms] = scaler.fit_transform(df[scaleclms])

# %%
y = df['CLM_AMT']
x = df.drop(columns=['CLM_AMT'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lin_reg = LinearRegression()

# %%
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 10222743.52
# Mean Absolute Error (MAE): 1075.97
# R-squared (R2): 0.35

# %%
x_train.shape
# Out:
# (8241, 43)

# %%
y_train.shape
# Out:
# (8241,)

# %%
param_grid = {
    'fit_intercept': [True, False],
     # 'normalize' is deprecated in newer versions of sklearn
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=lin_reg, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the GridSearchCV object
grid_search.fit(x_train, y_train)

# Get the best parameters and score
best_params = grid_search.best_params_
best_score = -grid_search.best_score_

print(f"Best Parameters: {best_params}")
print(f"Best Cross-Validation Mean Squared Error: {best_score:.2f}")

# Step 10: Fit the model with the best parameters and evaluate it
best_lin_reg = LinearRegression(**best_params)
best_lin_reg.fit(x_train, y_train)
y_pred_best = best_lin_reg.predict(x_test)

# Evaluate the best model
mse_best = mean_squared_error(y_test, y_pred_best)
r2_best = r2_score(y_test, y_pred_best)
mae_best = mean_absolute_error(y_test, y_pred_best)
print(f"Best Model Mean Squared Error (MSE): {mse_best:.2f}")
print(f"Best Model R-squared (R2): {r2_best:.2f}")
print(f"Mean Absolute Error (MAE) after tuning: {mae_best:.2f}")
# Out:
# Best Parameters: {'fit_intercept': True}
# Best Cross-Validation Mean Squared Error: 17660725.24
# Best Model Mean Squared Error (MSE): 10222743.52
# Best Model R-squared (R2): 0.35
# Mean Absolute Error (MAE) after tuning: 1075.97

# %%
# Predicted vs Actual values plot after tuning
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred_best)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=3)  # Line of perfect prediction
plt.xlabel("Actual Claim Amount")
plt.ylabel("Predicted Claim Amount (After Tuning)")
plt.title("Predicted vs Actual Claim Amount After Tuning")
plt.show()

# %%
# Residuals
residuals = y_test - y_pred

plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, color='blue', alpha=0.6)
plt.title('Residuals vs. Predicted Claim Amount')
plt.xlabel('Predicted Claim Amount')
plt.ylabel('Residuals')
plt.axhline(y=0, color='red', linestyle='--')
plt.grid()
plt.show()
